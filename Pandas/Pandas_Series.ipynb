# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
list_s=[1,45,18,"data"]
print(list_s)
# Out:
# [1, 45, 18, 'data']

# %%
series1 = pd.Series(list_s)
print(series1)
# Out:
# 0       1
# 1      45
# 2      18
# 3    data
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2=pd.Series([1,45,18,"data"])
print(series2)
# Out:
# 0       1
# 1      45
# 2      18
# 3    data
# dtype: object

# %%
empty_s=pd.Series([])
print(empty_s)
# Out:
# Series([], dtype: object)

# %%
series3=pd.Series([1,45,18,"data"], index=['a','b','c','d'])
print(series3)
# Out:
# a       1
# b      45
# c      18
# d    data
# dtype: object

# %%
series4=pd.Series([1,45,18,43], index=['a','b','c','d'], dtype=float)
print(series4)
# Out:
# a     1.0
# b    45.0
# c    18.0
# d    43.0
# dtype: float64

# %%
series4=pd.Series([1,45,18,43], index=['a','b','c','d'], dtype=float, name = "data values")
print(series4)
# Out:
# a     1.0
# b    45.0
# c    18.0
# d    43.0
# Name: data values, dtype: float64

# %%
scaler_s=pd.Series(0.5)
print(scaler_s)
# Out:
# 0    0.5
# dtype: float64

# %%
scaler_s=pd.Series(0.5, index=['a','b','c'])
print(scaler_s)
# Out:
# a    0.5
# b    0.5
# c    0.5
# dtype: float64

# %%
dict_1=pd.Series({'a':1,'b':2})
print(dict_1)
# Out:
# a    1
# b    2
# dtype: int64

# %%
series4[2]
# Out:
# C:\Users\shwet\AppData\Local\Temp\ipykernel_19944\281132966.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series4[2]
# 18.0

# %%
series4=pd.Series([1,45,18,43])
print(series4)
# Out:
# 0     1
# 1    45
# 2    18
# 3    43
# dtype: int64

# %%
series4[1]
# Out:
# 45

# %%
series4[0:3]
# Out:
# 0     1
# 1    45
# 2    18
# dtype: int64

# %%
max(series4)
# Out:
# 45

# %%
min(series4)
# Out:
# 1

# %%
series4[series4>3]
# Out:
# 1    45
# 2    18
# 3    43
# dtype: int64

# %%
series4
# Out:
# 0     1
# 1    45
# 2    18
# 3    43
# dtype: int64

# %%
s5=pd.Series([1,2,3,4,5])
print(s5)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series4+s5
# Out:
# 0     2.0
# 1    47.0
# 2    21.0
# 3    47.0
# 4     NaN
# dtype: float64
